# %%
# %conda install -y matplotlib
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.9.1
#     latest version: 26.7.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/miniconda3/envs/jiarong_elec576
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.13.2                 |       hce7a89e_0         2.2 MB
#     contourpy-1.3.3            |  py312h20e30b6_0        11.3 MB
#     cycler-0.12.1              |  py312hca03da5_0          19 KB
#     dav1d-1.5.3                |       h3e4eb2d_1         314 KB
#     fonttools-4.63.0           |  py312haa24f5a_0         6.0 MB
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 2, 7, 14])
plt.axis([0, 6, 0, 20])
plt.show()

# %%
plt.axis([0, 6, 0, 20])
# Out:
# (np.float64(0.0), np.float64(6.0), np.float64(0.0), np.float64(20.0))
